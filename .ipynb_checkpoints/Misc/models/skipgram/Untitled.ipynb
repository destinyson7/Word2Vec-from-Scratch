# %%
import json
import operator
import numpy as np
import matplotlib.pyplot as plt

# %%
file = open('cbow.json','r')

data = json.load(file)

word2index = data['word2Ind']
index2word = data['Ind2word']
costs = data['cost']
W_output = np.array(data['W2'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-3a4569a06472> in <module>
# ----> 1 file = open('cbow.json','r')
#       2
#       3 data = json.load(file)
#       4
#       5 word2index = data['word2Ind']
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cbow.json'

# %%
def word_sim(word, top_n):
		
	w1_index = word2index[word]
	v_w1 = W_output[w1_index]

		# CYCLE THROUGH VOCAB
	word_sim = {}

	for i in range(len(word2index)):
		v_w2 = W_output[i]
		theta_num = np.dot(v_w1, v_w2)
		theta_den = np.linalg.norm(v_w1) * np.linalg.norm(v_w2)
		theta = theta_num / theta_den

		word = index2word[str(i)]
		word_sim[word] = theta

	words_sorted = sorted(word_sim.items(), key=operator.itemgetter(1), reverse=True)
	ret = []
	
	for word, sim in words_sorted[:top_n+1]:
		ret.append(word)
		
	# print(i)

	return ret

# %%
# !ls
# Out:
# Untitled.ipynb	epoch0.json  epoch1.json

# %%
Words = ["quickly","throw","awesome","hard","computer"]

# %%
for word in Words:

	top_words = word_sim(word, 11)
	keys = list(top_words)
	# keys.append(word)
	visualizeWords = keys
	visualizeIdx = [word2index[word] for word in visualizeWords]
	visualizeVecs = W_output[visualizeIdx, :]
	temp = (visualizeVecs - np.mean(visualizeVecs, axis=0))
	covariance = 1.0 / len(visualizeIdx) * temp.T.dot(temp)
	U,S,V = np.linalg.svd(covariance)
	coord = temp.dot(U[:,0:2])

	for i in range(len(visualizeWords)):
		plt.text(coord[i,0], coord[i,1], visualizeWords[i],
			bbox=dict(facecolor='green', alpha=0.1))

	plt.xlim((np.min(coord[:,0]), np.max(coord[:,0])))
	plt.ylim((np.min(coord[:,1]), np.max(coord[:,1])))
	plt.title('Closest 10 vectors to ' + word)
	plt.show()

# %%
print(word_sim("camera", 11))
print()
print()
# Out:
# ['camera', 'rebel', 'dslr', 'canon', 'lense', 'film', 'lens', 'camcorder', 'slr', 'sensor', 'mm', 'kit']
